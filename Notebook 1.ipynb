# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('dataset_1.xlsx')
df.head(610)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
df['dteday'] = pd.to_datetime(df['dteday'])

df['day'] = df['dteday'].dt.day
df['month'] = df['dteday'].dt.month
df['year'] = df['dteday'].dt.year

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['season'] = le.fit_transform(df['season'])
df['weathersit'] = le.fit_transform(df['weathersit'])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['temp']] = scaler.fit_transform(df[['temp']])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['temp']] = scaler.fit_transform(df[['temp']])

# %%
print(df.isnull().sum())
# No missing values in this case
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# day           0
# month         0
# year          0
# dtype: int64

# %%
# No columns seem unnecessary in this case
# df = df.drop('column_name', axis=1)

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 610
# Number of columns: 13

# %%
print(df.dtypes)
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# day                    int32
# month                  int32
# year                   int32
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  day         610 non-null    int32
#  11  month       610 non-null    int32
#  12  year        610 non-null    int32
# dtypes: bool(1), datetime64[ns](1), float64(1), int32(3), int64(7)
# memory usage: 50.8 KB
# None

# %%
print(df.isnull().sum())
# No missing values in this case
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# day           0
# month         0
# year          0
# dtype: int64

# %%
# Convert dteday to datetime format
df['dteday'] = pd.to_datetime(df['dteday'])

# %%
print(df.describe())
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     0.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     0.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     0.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     0.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     0.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     0.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit          temp         day  month  \
# count  610.000000  610.000000  610.000000  6.100000e+02  610.000000  610.0
# mean    11.795082    2.977049    0.477049  3.494472e-17   13.824590    1.0
# min      0.000000    0.000000    0.000000 -2.177393e+00    1.000000    1.0
# ...

# %%
df.to_csv('output.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['temp'], kde=True)
plt.title('Temperature Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['hr'], y=df['temp'])
plt.title('Hourly Temperature Trend')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['weekday'], y=df['temp'])
plt.title('Temperature by Weekday')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=df['weathersit'])
plt.title('Weather Situation Distribution')
plt.show()

# %%
df=pd.read_excel('dataset_2.xlsx')
df.head(610)
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
scaler = StandardScaler()
df[['atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']] = scaler.fit_transform(df[['atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']])

# %%
for column in df.columns:
    print(f"Unique values in {column}: {df[column].nunique()}")
# Out:
# Unique values in Unnamed: 0: 610
# Unique values in instant: 610
# Unique values in atemp: 29
# Unique values in hum: 61
# Unique values in windspeed: 20
# Unique values in casual: 32
# Unique values in registered: 150
# Unique values in cnt: 165

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

print(df.dtypes)
# Out:
# Number of rows: 610
# Number of columns: 7
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual        float64
# registered    float64
# cnt           float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   atemp       599 non-null    float64
#  2   hum         610 non-null    float64
#  3   windspeed   610 non-null    float64
#  4   casual      610 non-null    float64
#  5   registered  610 non-null    float64
#  6   cnt         610 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 33.5 KB
# None

# %%
print(df.describe())
# Out:
#           instant         atemp           hum     windspeed        casual  \
# count  610.000000  5.990000e+02  6.100000e+02  6.100000e+02  6.100000e+02
# mean   305.500000  7.117290e-17 -6.406533e-17  4.659297e-17  1.164824e-17
# std    176.236111  1.000836e+00  1.000821e+00  1.000821e+00  1.000821e+00
# min      1.000000 -2.538217e+00 -2.010741e+00 -1.683162e+00 -7.128755e-01
# 25%    153.250000 -6.148916e-01 -7.414613e-01 -8.245359e-01 -7.128755e-01
# 50%    305.500000 -3.725909e-02 -2.423064e-01 -8.915732e-02 -3.961573e-01
# 75%    457.750000  5.391039e-01  7.274802e-01  6.470429e-01  2.372790e-01
# max    610.000000  3.231760e+00  2.495915e+00  3.099674e+00  6.730001e+00
#
#          registered           cnt
# count  6.100000e+02  6.100000e+02
# mean   5.241709e-17  6.988945e-17
# std    1.000821e+00  1.000821e+00
# min   -1.086973e+00 -1.107438e+00
# 25%   -7.889903e-01 -8.030319e-01
# 50%   -1.717411e-01 -1.739270e-01
# 75%    4.029392e-01  4.906918e-01
# ...

# %%
df.to_csv('output1.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['cnt'], kde=True)
plt.title('Distribution of Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['atemp'], y=df['cnt'])
plt.title('Relationship between Temperature and Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['hum'], y=df['cnt'])
plt.title('Relationship between Humidity and Count')
plt.show()

# %%
from pandas.plotting import scatter_matrix

plt.figure(figsize=(12, 8))
scatter_matrix(df, diagonal='kde')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
# Load the CSV files
df1 = pd.read_csv('output.csv')
df2 = pd.read_csv('output1.csv')

# %%
# Merge the datasets based on the 'instant' column
merged_df = pd.merge(df1, df2, on='instant')

# %%
# Save the merged dataset to a new CSV file
merged_df.to_csv('merged_output.csv', index=False)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('merged_output.csv')
df.head(610)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       0   0     1   0    False        6           0
# 1          2  2011-01-01       0   0     1   1    False        6           0
# 2          3  2011-01-01       0   0     1   2    False        6           0
# 3          4  2011-01-01       0   0     1   3    False        6           0
# 4          5  2011-01-01       0   0     1   4    False        6           0
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  2011-01-28       0   0     1  11    False        5           2
# 606      607  2011-01-28       0   0     1  12    False        5           2
# 607      608  2011-01-28       0   0     1  13    False        5           2
# 608      609  2011-01-28       0   0     1  14    False        5           2
# 609      610  2011-01-28       0   0     1  15    False        5           1
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['cnt'], kde=True)
plt.title('Distribution of Bike Rentals')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['season'], y=df['cnt'])
plt.title('Seasonal Trends in Bike Rentals')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['weathersit'], y=df['cnt'])
plt.title('Weather Impact on Bike Rentals')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df['hr'], y=df['cnt'])
plt.title('Hourly Trends in Bike Rentals')
plt.show()
